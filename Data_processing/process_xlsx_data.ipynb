# %%
import pandas as pd
df= pd.read_excel('data_raw.xlsx')

# %%
df
# Out:
#      id                                               user  \
# 0   1.0                                                NaN
# 1   NaN                               em treo lâu chưa vậy
# 2   NaN                               em bị treo bao nhiêu
# 3   NaN                                         app nào em
# 4   NaN                                       cho anh bill
# 5   NaN                                         sao rồi em
# 6   NaN  giờ em cọc giúp anh 300k nha làm 30 phút đến 1...
# 7   NaN  Làm xong là về nha em Nhưng mà của em lâu rồi ...
# 8   NaN                                 Tran Vu Ngoc Thien
# 9   NaN              Cọc cho anh thì không phải ghi nha em
# 10  NaN                                                NaN
# 11  2.0                                                NaN
# 12  NaN  Chụp gửi thông tin mình xem bạn Xem nó treo th...
# 13  NaN                         Bạn vào tiền bao nhiêu lâu
# 14  NaN  Sau khi treo tổng bạn đã chuyển khoản thêm cho...
# ...

# %%
df = df.reset_index()
df
# Out:
#     index   id                                               user  \
# 0       0  1.0                                                NaN
# 1       1  NaN                               em treo lâu chưa vậy
# 2       2  NaN                               em bị treo bao nhiêu
# 3       3  NaN                                         app nào em
# 4       4  NaN                                       cho anh bill
# 5       5  NaN                                         sao rồi em
# 6       6  NaN  giờ em cọc giúp anh 300k nha làm 30 phút đến 1...
# 7       7  NaN  Làm xong là về nha em Nhưng mà của em lâu rồi ...
# 8       8  NaN                                 Tran Vu Ngoc Thien
# 9       9  NaN              Cọc cho anh thì không phải ghi nha em
# 10     10  NaN                                                NaN
# 11     11  2.0                                                NaN
# 12     12  NaN  Chụp gửi thông tin mình xem bạn Xem nó treo th...
# ...

# %%
data = []
for index, row in df.iterrows():
    if str(row['user']) != 'nan':
        user_AI = {
            'user': str(row['user']),
            'AI': str(row['AI'])
        }
        data.append(user_AI)

# %%
data
# Out:
# [{'user': 'em treo lâu chưa vậy', 'AI': 'em bị cũng lâu rồi anh ạ'},
#  {'user': 'em bị treo bao nhiêu', 'AI': 'em bị lừa 20.000.000đ anh ạ'},
#  {'user': 'app nào em', 'AI': 'em bị lừa qua zalo anh ạ'},
#  {'user': 'cho anh bill',
#   'AI': 'anh đợi em chút em tìm lại đã, tại cũng lâu rồi ạ'},
#  {'user': 'sao rồi em', 'AI': 'anh chờ em chút anh ơi em tìm đươc rồi'},
#  {'user': 'giờ em cọc giúp anh 300k nha làm 30 phút đến 1 giờ là xong 14122220305199 mb',
#   'AI': 'anh ơi vậy là 1 giờ sau là tiền được trả về à anh'},
#  {'user': 'Làm xong là về nha em Nhưng mà của em lâu rồi chắc không về đủ 20 triệu đâu',
#   'AI': 'anh cho em xin đầy đủ số tài khoản với cả tên luôn ạ em sợ chuyển khoản nhầm'},
#  {'user': 'Tran Vu Ngoc Thien', 'AI': 'với có cần ghi nội dung gì không ạ'},
#  {'user': 'Cọc cho anh thì không phải ghi nha em', 'AI': 'vâng anh'},
#  {'user': 'Chụp gửi thông tin mình xem bạn Xem nó treo thật Hay bọn lừa đảo',
# ...

# %%
from utils import write_json_file
write_json_file(data, 'data/data.json')

# %%
from openai import OpenAI
client = OpenAI()

completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {
            "role": "user",
            "content": "Write a haiku about recursion in programming."
        }
    ]
)

print(completion.choices[0].message)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 from openai import OpenAI
# ----> 2 client = OpenAI()
#       4 completion = client.chat.completions.create(
#       5     model="gpt-4o-mini",
#       6     messages=[
#    (...)
#      12     ]
#      13 )
#      15 print(completion.choices[0].message)
#
# File d:\envs\luadao_chatbot\Lib\site-packages\openai\_client.py:123, in OpenAI.__init__(self, api_key, organization, project, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     120 if base_url is None:
#     121     base_url = f"https://api.openai.com/v1"
# --> 123 super().__init__(
#     124     version=__version__,
#     125     base_url=base_url,
#     126     max_retries=max_retries,
#     127     timeout=timeout,
#     128     http_client=http_client,
# ...

# %%
import re
response = " Dạ vâng, em gửi anh bill ạ. Đây là link ảnh bill: [hỏi chấm.jpg](#). Anh kiểm tra giúp em nhé!"
pattern = r'\[(.*?)*\]\(\#\)'
json_match = re.search(pattern, response, re.DOTALL)
if json_match != None:
    content_json = json_match.group(0)
    image_name = content_json.replace("[", "")\
                            .replace("](#)", "")
image_name
# Out:
# <re.Match object; span=(51, 68), match='[hỏi chấm.jpg](#)'>
# 'hỏi chấm.jpg'
